# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("laptop_data.csv")

# %%
df.sample(3)
# Out:
#       Unnamed: 0 Company TypeName  Inches             ScreenResolution  \
# 1247        1247    Asus   Gaming    15.6  IPS Panel Full HD 1920x1080
# 428          428      HP   Gaming    17.3            Full HD 1920x1080
# 658          658  Lenovo   Gaming    15.6  IPS Panel Full HD 1920x1080
#
#                               Cpu   Ram                Memory  \
# 1247  Intel Core i7 6700HQ 2.6GHz  16GB  256GB SSD +  1TB HDD
# 428   Intel Core i7 7700HQ 2.8GHz  12GB  256GB SSD +  1TB HDD
# 658   Intel Core i7 6700HQ 2.6GHz   8GB  128GB SSD +  1TB HDD
#
#                           Gpu       OpSys  Weight      Price
# 1247  Nvidia GeForce GTX 1070  Windows 10  2.34kg  123876.00
# 428   Nvidia GeForce GTX 1070  Windows 10  3.35kg  106506.72
# 658    Nvidia GeForce GTX 960  Windows 10  3.31kg   63722.88

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop(columns=["Unnamed: 0"],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
df["Ram"]=df["Ram"].str.replace("GB","")
df["Weight"]=df["Weight"].str.replace("kg","")

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# 3            AMD Radeon Pro 455  macOS   1.83  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS   1.37   96095.8080

# %%
df["Ram"]=df["Ram"].astype('int32')
df["Weight"]=df["Weight"].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %%
sns.distplot(df["Price"])
# Out:
# C:\Users\SUBHAM\AppData\Local\Temp\ipykernel_24204\941010651.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Price"])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df["Company"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x=df["Company"],y=df["Price"])
plt.xticks(rotation=90)
plt.show()

# %%
df["TypeName"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=df["TypeName"],y=df["Price"])
plt.xticks(rotation=90)
plt.show()

# %%
sns.distplot(df["Inches"])
# Out:
# C:\Users\SUBHAM\AppData\Local\Temp\ipykernel_24204\2945259378.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Inches"])
# <Axes: xlabel='Inches', ylabel='Density'>

# %%
sns.scatterplot(x=df["Inches"],y=df["Price"])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
df["ScreenResolution"].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Retina Display 2880x1800                 4
# IPS Panel Touchscreen 1920x1200                    4
# 1440x900                                           4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ 2560x1440                       3
# Quad HD+ 3200x1800                                 3
# 1920x1080                                          3
# Touchscreen 2400x1600                              3
# 2560x1440                                          3
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Retina Display 2736x1824                 1
# IPS Panel Full HD 1920x1200                        1
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Full HD 1920x1080                    1
# Touchscreen / Quad HD+ 3200x1800                   1
# Touchscreen / 4K Ultra HD 3840x2160                1
# IPS Panel Touchscreen 2400x1600                    1
# Name: count, dtype: int64

# %%
df["TouchScreen"]=df["ScreenResolution"].apply(lambda x:1 if "Touchscreen" in x else 0)

# %%
df.sample(2)
# Out:
#      Company  TypeName  Inches   ScreenResolution                         Cpu  \
# 1078  Lenovo  Notebook    15.6           1366x768  Intel Core i5 6200U 2.3GHz
# 29        HP  Notebook    17.3  Full HD 1920x1080  Intel Core i5 8250U 1.6GHz
#
#       Ram     Memory                    Gpu       OpSys  Weight     Price  \
# 1078    4  500GB HDD  Intel HD Graphics 520  Windows 10     2.1  28771.20
# 29      8    1TB HDD   Nvidia GeForce 930MX  Windows 10     2.5  47738.88
#
#       TouchScreen
# 1078            0
# 29              0

# %%
df["TouchScreen"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='TouchScreen'>

# %%
sns.barplot(x=df["TouchScreen"],y=df["Price"])
plt.xticks(rotation=90)
plt.show()

# %%
df["Ips"]=df["ScreenResolution"].apply(lambda x:1 if "IPS" in x else 0)

# %%
df.head(2)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
#
#                     Cpu  Ram               Memory  \
# 0  Intel Core i5 2.3GHz    8            128GB SSD
# 1  Intel Core i5 1.8GHz    8  128GB Flash Storage
#
#                             Gpu  OpSys  Weight       Price  TouchScreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34  47895.5232            0    0

# %%
df["Ips"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Ips'>

# %%
sns.barplot(x=df["Ips"],y=df["Price"])
# Out:
# <Axes: xlabel='Ips', ylabel='Price'>

# %%
new=df["ScreenResolution"].str.split("x",n=1,expand=True)
df["x_resolution"]=new[0]
df["y_resolution"]=new[1]

# %%
df.sample(2)
# Out:
#      Company  TypeName  Inches   ScreenResolution                         Cpu  \
# 1176  Lenovo  Notebook    15.6  Full HD 1920x1080  Intel Core i7 6500U 2.5GHz
# 16      Dell  Notebook    15.6  Full HD 1920x1080  Intel Core i7 7500U 2.7GHz
#
#       Ram        Memory                    Gpu       OpSys  Weight    Price  \
# 1176    4  1.0TB Hybrid  Intel HD Graphics 520   Windows 7    2.32  43956.0
# 16      8     256GB SSD     AMD Radeon R5 M430  Windows 10    2.20  39693.6
#
#       TouchScreen  Ips  x_resolution y_resolution
# 1176            0    0  Full HD 1920         1080
# 16              0    0  Full HD 1920         1080

# %%
df["x_resolution"] = (
    df["x_resolution"]
    .astype(str)
    .str.replace(",", "")
    .str.findall(r'(\d+\.?\d+)')
    .apply(lambda x: x[0])
)

# %%
df.head(2)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
#
#                     Cpu  Ram               Memory  \
# 0  Intel Core i5 2.3GHz    8            128GB SSD
# 1  Intel Core i5 1.8GHz    8  128GB Flash Storage
#
#                             Gpu  OpSys  Weight       Price  TouchScreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34  47895.5232            0    0
#
#   x_resolution y_resolution
# 0         2560         1600
# 1         1440          900

# %%
df["Price"]=df["Price"].astype('int64')
df["x_resolution"]=df["x_resolution"].astype('int64')
df["y_resolution"]=df["y_resolution"].astype('int64')

# %%
df.sample(3)
# Out:
#     Company            TypeName  Inches  \
# 85     Dell              Gaming    15.6
# 905      LG           Ultrabook    15.6
# 596  Lenovo  2 in 1 Convertible    13.3
#
#                               ScreenResolution                          Cpu  \
# 85                 IPS Panel Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
# 905  IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i7 7500U 2.7GHz
# 596  IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i7 7500U 2.7GHz
#
#      Ram                Memory                         Gpu       OpSys  \
# 85    16  128GB SSD +  1TB HDD  Nvidia GeForce GTX 1050 Ti  Windows 10
# 905   16             512GB SSD       Intel HD Graphics 620  Windows 10
# 596    8             512GB SSD       Intel HD Graphics 620  Windows 10
#
#      Weight   Price  TouchScreen  Ips  x_resolution  y_resolution
# 85     2.65   71874            0    1          1920          1080
# 905    1.08  111834            1    1          1920          1080
# 596    1.37  107892            1    1          1920          1080

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   int64
#  11  TouchScreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  x_resolution      1303 non-null   int64
#  14  y_resolution      1303 non-null   int64
# dtypes: float32(1), float64(1), int32(1), int64(5), object(7)
# memory usage: 142.6+ KB

# %%
df["Ppi"]=((df["x_resolution"]**2)+(df["y_resolution"]**2)**0.5)/df["Inches"]

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  TouchScreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095            0    1
#
#    x_resolution  y_resolution            Ppi
# 0          2560          1600  492872.180451
# 1          1440           900  155977.443609
# 2          1920          1080  236376.923077
# 3          2880          1800  538714.285714
# 4          2560          1600  492872.180451

# %%
df["Ppi"]=df["Ppi"].astype("float64")

# %%
df.head(2)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
#
#                     Cpu  Ram               Memory  \
# 0  Intel Core i5 2.3GHz    8            128GB SSD
# 1  Intel Core i5 1.8GHz    8  128GB Flash Storage
#
#                             Gpu  OpSys  Weight  Price  TouchScreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378            0    1
# 1        Intel HD Graphics 6000  macOS    1.34  47895            0    0
#
#    x_resolution  y_resolution            Ppi
# 0          2560          1600  492872.180451
# 1          1440           900  155977.443609

# %%
df.drop(columns=["ScreenResolution"],axis=1,inplace=True)

# %%
df.sample(3)
# Out:
#     Company  TypeName  Inches                                   Cpu  Ram  \
# 503  Lenovo  Notebook    14.0  Intel Celeron Dual Core N3350 1.1GHz    4
# 365      HP  Notebook    15.6  Intel Pentium Quad Core N3710 1.6GHz    8
# 91     Acer  Notebook    15.6            Intel Core i7 8550U 1.8GHz    8
#
#         Memory                    Gpu       OpSys  Weight  Price  TouchScreen  \
# 503  500GB HDD  Intel HD Graphics 500  Windows 10    2.10  15930            0
# 365    2TB HDD  Intel HD Graphics 405  Windows 10    2.04  20725            0
# 91     1TB HDD   Nvidia GeForce MX150  Windows 10    2.20  36709            0
#
#      Ips  x_resolution  y_resolution            Ppi
# 503    0          1366           768  133337.428571
# 365    0          1366           768  119661.794872
# 91     0          1920          1080  236376.923077

# %%
df.drop(columns=["Inches","x_resolution","y_resolution"],axis=1,inplace=True)

# %%
df.sample(3)
# Out:
#      Company  TypeName                                   Cpu  Ram  \
# 383   Lenovo  Notebook            Intel Core i5 7200U 2.5GHz    8
# 503   Lenovo  Notebook  Intel Celeron Dual Core N3350 1.1GHz    4
# 1141     MSI    Gaming           Intel Core i7 7700HQ 2.8GHz    8
#
#                     Memory                      Gpu       OpSys  Weight  \
# 383              256GB SSD     Nvidia GeForce 940MX  Windows 10     1.5
# 503              500GB HDD    Intel HD Graphics 500  Windows 10     2.1
# 1141  128GB SSD +  1TB HDD  Nvidia GeForce GTX 1050  Windows 10     2.4
#
#       Price  TouchScreen  Ips            Ppi
# 383   58554            0    1  263391.428571
# 503   15930            0    0  133337.428571
# 1141  60888            0    0  236376.923077

# %%
df["Cpu_name"]=df["Cpu"].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  TouchScreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095            0    1
#
#              Ppi       Cpu_name
# 0  492872.180451  Intel Core i5
# 1  155977.443609  Intel Core i5
# 2  236376.923077  Intel Core i5
# 3  538714.285714  Intel Core i7
# 4  492872.180451  Intel Core i5

# %%
def fetch_processor(text):
    if text=="Intel Core i7" or text=="Intel Core i5" or text=="Intel Core i3":
        return text
    else:
         if text.split()[0]=="Intel":
             return "Other Intel Processor"
         else:
             return "AMD Processors"

# %%
df["Cpu_brand"]=df["Cpu_name"].apply(fetch_processor)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  TouchScreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095            0    1
#
#              Ppi       Cpu_name      Cpu_brand
# 0  492872.180451  Intel Core i5  Intel Core i5
# 1  155977.443609  Intel Core i5  Intel Core i5
# 2  236376.923077  Intel Core i5  Intel Core i5
# 3  538714.285714  Intel Core i7  Intel Core i7
# 4  492872.180451  Intel Core i5  Intel Core i5

# %%
df.shape
# Out:
# (1303, 14)

# %%
df["Cpu_brand"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Cpu_brand'>

# %%
sns.barplot(x=df["Cpu_brand"],y=df["Price"])
plt.xticks(rotation=90)
plt.show()

# %%
df.drop(columns=["Cpu","Cpu_name"],axis=1,inplace=True)

# %%
df.sample(5)
# Out:
#      Company            TypeName  Ram                Memory  \
# 672   Lenovo  2 in 1 Convertible    8             256GB SSD
# 1278    Dell            Notebook    2             500GB HDD
# 657     Dell            Notebook   16  256GB SSD +  2TB HDD
# 311     Dell           Ultrabook   16               1TB SSD
# 835     Dell              Gaming   16  256GB SSD +  1TB HDD
#
#                           Gpu       OpSys  Weight   Price  TouchScreen  Ips  \
# 672     Intel HD Graphics 620  Windows 10    1.30   55091            1    1
# 1278        Intel HD Graphics  Windows 10    2.20   20193            0    0
# 657            AMD Radeon 530  Windows 10    2.20   60472            0    0
# 311    Intel UHD Graphics 620  Windows 10    1.21  133146            1    1
# 835   Nvidia GeForce GTX 1070  Windows 10    3.21  147832            0    0
#
#                Ppi              Cpu_brand
# 672   2.772541e+05          Intel Core i5
# 1278  1.196618e+05  Other Intel Processor
# 657   2.363769e+05          Intel Core i7
# 311   1.108854e+06          Intel Core i7
# 835   2.363769e+05          Intel Core i7

# %%
df["Ram"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Ram'>

# %%
sns.barplot(x=df["Ram"],y=df["Price"])
plt.xticks(rotation=90)
plt.show()

# %%
df["Memory"].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB SSD +  256GB SSD             1
# 512GB SSD +  512GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 1TB HDD +  1TB HDD                 1
# 32GB HDD                           1
# 64GB SSD                           1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: count, dtype: int64

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)

df["Memory"] = df["Memory"].str.replace('GB', '', regex=False)
df["Memory"] = df["Memory"].str.replace('TB', '000', regex=False)

new = df["Memory"].str.split("+", n=1, expand=True)

df["first"] = new[0].str.strip()
df["second"] = new[1]

# Layer 1
df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# Remove non-digits
df['first'] = df['first'].str.replace(r'\D', '', regex=True)

# Fix warning
df["second"] = df["second"].fillna("0")

# Layer 2
df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# Remove non-digits
df['second'] = df['second'].str.replace(r'\D', '', regex=True)

# Convert to int
df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

# Final storage columns
df["HDD"] = (
    df["first"] * df["Layer1HDD"] +
    df["second"] * df["Layer2HDD"]
)

df["SSD"] = (
    df["first"] * df["Layer1SSD"] +
    df["second"] * df["Layer2SSD"]
)

df["Hybrid"] = (
    df["first"] * df["Layer1Hybrid"] +
    df["second"] * df["Layer2Hybrid"]
)

df["Flash_Storage"] = (
    df["first"] * df["Layer1Flash_Storage"] +
    df["second"] * df["Layer2Flash_Storage"]
)

# Drop extra columns
df.drop(columns=[
    'first', 'second',
    'Layer1HDD', 'Layer1SSD',
    'Layer1Hybrid', 'Layer1Flash_Storage',
    'Layer2HDD', 'Layer2SSD',
    'Layer2Hybrid', 'Layer2Flash_Storage'
], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight   Price  TouchScreen  Ips            Ppi      Cpu_brand  HDD  \
# 0  macOS    1.37   71378            0    1  492872.180451  Intel Core i5    0
# 1  macOS    1.34   47895            0    0  155977.443609  Intel Core i5    0
# 2  No OS    1.86   30636            0    0  236376.923077  Intel Core i5    0
# 3  macOS    1.83  135195            0    1  538714.285714  Intel Core i7    0
# 4  macOS    1.37   96095            0    1  492872.180451  Intel Core i5    0
#
#    SSD  Hybrid  Flash_Storage
# 0  128       0              0
# 1    0       0            128
# 2  256       0              0
# 3  512       0              0
# 4  256       0              0

# %%
df.drop(columns=["Memory"],axis=1,inplace=True)

# %%
df.drop(columns=["Hybrid","Flash_Storage"],inplace=True)

# %%
df.sample(3)
# Out:
#      Company            TypeName  Ram                      Gpu       OpSys  \
# 1185    Asus              Gaming    8  Nvidia GeForce GTX 960M  Windows 10
# 1271  Lenovo  2 in 1 Convertible   16    Intel HD Graphics 520  Windows 10
# 61      Dell           Ultrabook    8   Intel UHD Graphics 620  Windows 10
#
#       Weight  Price  TouchScreen  Ips            Ppi      Cpu_brand   HDD  SSD
# 1185   2.591  48431            0    1  236376.923077  Intel Core i7  1000  256
# 1271   1.300  79866            1    1  770060.150376  Intel Core i7     0  512
# 61     1.700  46833            0    0  263391.428571  Intel Core i5     0  256

# %%
df["Gpu_brand"]=df["Gpu"].apply(lambda x:x.split()[0])

# %%
df.sample(3)
# Out:
#       Company            TypeName  Ram                      Gpu       OpSys  \
# 771   Samsung  2 in 1 Convertible   16           AMD Radeon 540  Windows 10
# 954    Lenovo           Ultrabook    8    Intel HD Graphics 520  Windows 10
# 1195       HP            Notebook   12  Nvidia GeForce GTX 1050  Windows 10
#
#       Weight  Price  TouchScreen  Ips            Ppi      Cpu_brand   HDD  \
# 771     1.71  95850            1    0  245832.000000  Intel Core i7     0
# 954     1.70  79333            0    1  263391.428571  Intel Core i7     0
# 1195    2.21  70702            0    1  236376.923077  Intel Core i7  1000
#
#       SSD Gpu_brand
# 771   256       AMD
# 954   256     Intel
# 1195  128    Nvidia

# %%
df["Gpu_brand"].value_counts()
# Out:
# Gpu_brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df=df[df["Gpu_brand"]!="ARM"]

# %%
df["Gpu_brand"].value_counts()
# Out:
# Gpu_brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
sns.barplot(x=df["Gpu_brand"],y=df["Price"])
plt.xticks(rotation=90)
plt.show()

# %%
df.drop(columns=["Gpu"],inplace=True)

# %%
df.sample(3)
# Out:
#      Company   TypeName  Ram       OpSys  Weight   Price  TouchScreen  Ips  \
# 780     Dell     Gaming   32  Windows 10    4.42  191211            0    1
# 774       HP  Ultrabook    4  Windows 10    1.26   66280            0    0
# 1001      HP   Notebook    8  Windows 10    1.34   63349            0    1
#
#                 Ppi      Cpu_brand   HDD   SSD Gpu_brand
# 780   213149.132948  Intel Core i7  1000  1000    Nvidia
# 774   149337.920000  Intel Core i5     0   256     Intel
# 1001  277254.135338  Intel Core i5     0   256     Intel

# %%
df["OpSys"].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
sns.barplot(x=df["OpSys"],y=df["Price"])
plt.xticks(rotation=90)
plt.show()

# %%
def cat_os(inp):
    if inp=="Windows 10" or inp=="Windows 7" or inp=="Windows 10 S":
        return "Windows"
    elif inp=="macOS" or inp=="Mac OS X":
        return "mac"
    else:
        return "Other/No OS"

# %%
df["OS"]=df["OpSys"].apply(cat_os)

# %%
df.sample(10)
# Out:
#      Company            TypeName  Ram       OpSys  Weight   Price  \
# 830    Razer              Gaming   32  Windows 10    3.49  292986
# 962     Acer            Notebook   12  Windows 10    2.40   53759
# 562       HP           Ultrabook   16  Windows 10    1.16  104695
# 7      Apple           Ultrabook    8       macOS    1.34   61735
# 896     Dell              Gaming    8       Linux    2.62   49497
# 374     Dell  2 in 1 Convertible    8  Windows 10    1.62   46300
# 1079      HP            Notebook    4   Windows 7    2.31   50083
# 1114  Lenovo  2 in 1 Convertible    4     Android    0.69   29250
# 447     Dell         Workstation    8  Windows 10    2.23  106187
# 594   Lenovo            Notebook    4       No OS    2.80   28185
#
#       TouchScreen  Ips            Ppi              Cpu_brand   HDD  SSD  \
# 830             1    0  852471.676301          Intel Core i7     0  512
# 962             0    0  236376.923077          Intel Core i5  1000  128
# 562             1    1  770060.150376  Other Intel Processor     0  512
# 7               0    0  155977.443609          Intel Core i5     0    0
# 896             0    0  236376.923077          Intel Core i7  1000    0
# 374             1    0  277254.135338          Intel Core i7     0  256
# 1079            0    0  236376.923077          Intel Core i5   500    0
# 1114            1    1  365108.910891  Other Intel Processor     0    0
# 447             0    0  236376.923077  Other Intel Processor  1000    0
# 594             0    0  213149.132948          Intel Core i3   500    0
#
#      Gpu_brand           OS
# 830     Nvidia      Windows
# 962     Nvidia      Windows
# 562      Intel      Windows
# 7        Intel          mac
# 896     Nvidia  Other/No OS
# 374      Intel      Windows
# 1079     Intel      Windows
# 1114     Intel  Other/No OS
# 447     Nvidia      Windows
# 594      Intel  Other/No OS

# %%
df.drop(columns=["OpSys"],inplace=True)

# %%
sns.barplot(x=df["OS"],y=df["Price"])
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=df["Weight"],y=df["Price"])
plt.xticks(rotation=90)
plt.show()

# %%
sns.distplot(df["Weight"])
# Out:
# C:\Users\SUBHAM\AppData\Local\Temp\ipykernel_24204\196129849.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Weight"])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=df["Weight"],y=df["Price"])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
sns.distplot(df["Price"])
# Out:
# C:\Users\SUBHAM\AppData\Local\Temp\ipykernel_24204\941010651.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Price"])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
x=df.drop(columns=["Price"])
y=np.log(df["Price"])

# %%
x.shape
# Out:
# (1302, 12)

# %%
y.shape
# Out:
# (1302,)

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=41)

# %%
x_train.shape,y_train.shape
# Out:
# ((1041, 12), (1041,))

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso,SGDRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor

# %%
#Linear regression model



step1=ColumnTransformer(transformers=[
    ("col_trf",OneHotEncoder(sparse_output=False,drop="first"),[0,1,7,10,11])
],
remainder="passthrough")


step2=LinearRegression()

pipe=Pipeline([
    ("step1",step1),
    ("step2",step2)
])

pipe.fit(x_train,y_train)

y_pred=pipe.predict(x_test)

from sklearn.metrics import r2_score,accuracy_score,mean_absolute_error

print("r2_score: " ,r2_score(y_test,y_pred))
print("error: ",mean_absolute_error(y_test,y_pred))
# Out:
# r2_score:  0.8152061316108037
# error:  0.21447912316049017

# %%
#ridge regression


step1=ColumnTransformer(transformers=[
    ("col_trf",OneHotEncoder(sparse_output=False,drop="first"),[0,1,7,10,11])
],
remainder="passthrough")


step2=Ridge(alpha=10)

pipe=Pipeline([
    ("step1",step1),
    ("step2",step2)
])

pipe.fit(x_train,y_train)

y_pred=pipe.predict(x_test)

from sklearn.metrics import r2_score,accuracy_score,mean_absolute_error

print("r2_score: " ,r2_score(y_test,y_pred))
print("error: ",mean_absolute_error(y_test,y_pred))
# Out:
# r2_score:  0.8035134075647423
# error:  0.2205296420023413

# %%
#lasso regressor model


step1=ColumnTransformer(transformers=[
    ("col_trf",OneHotEncoder(sparse_output=False,drop="first"),[0,1,7,10,11])
],
remainder="passthrough")


step2=Lasso(alpha=0.001)

pipe=Pipeline([
    ("step1",step1),
    ("step2",step2)
])

pipe.fit(x_train,y_train)

y_pred=pipe.predict(x_test)

from sklearn.metrics import r2_score,accuracy_score,mean_absolute_error

print("r2_score: " ,r2_score(y_test,y_pred))
print("error: ",mean_absolute_error(y_test,y_pred))
# Out:
# r2_score:  0.8036485784629231
# error:  0.22177299844188206

# %%
#knn


step1=ColumnTransformer(transformers=[
    ("col_trf",OneHotEncoder(sparse_output=False,drop="first"),[0,1,7,10,11])
],
remainder="passthrough")


step2=KNeighborsRegressor(n_neighbors=3)

pipe=Pipeline([
    ("step1",step1),
    ("step2",step2)
])

pipe.fit(x_train,y_train)

y_pred=pipe.predict(x_test)

from sklearn.metrics import r2_score,accuracy_score,mean_absolute_error

print("r2_score: " ,r2_score(y_test,y_pred))
print("error: ",mean_absolute_error(y_test,y_pred))
# Out:
# r2_score:  0.8026795706078398
# error:  0.22044926801067757

# %%
#decisiontree regressor model


step1=ColumnTransformer(transformers=[
    ("col_trf",OneHotEncoder(sparse_output=False,drop="first"),[0,1,7,10,11])
],
remainder="passthrough")


step2=DecisionTreeRegressor(max_depth=8)

pipe=Pipeline([
    ("step1",step1),
    ("step2",step2)
])

pipe.fit(x_train,y_train)

y_pred=pipe.predict(x_test)

from sklearn.metrics import r2_score,accuracy_score,mean_absolute_error

print("r2_score: " ,r2_score(y_test,y_pred))
print("error: ",mean_absolute_error(y_test,y_pred))
# Out:
# r2_score:  0.8312788100873948
# error:  0.1950015085140552

# %%
#svr model


step1=ColumnTransformer(transformers=[
    ("col_trf",OneHotEncoder(sparse_output=False,drop="first"),[0,1,7,10,11])
],
remainder="passthrough")


step2=SVR(kernel="poly",C=1000,epsilon=0.1)

pipe=Pipeline([
    ("step1",step1),
    ("step2",step2)
])

pipe.fit(x_train,y_train)

y_pred=pipe.predict(x_test)

from sklearn.metrics import r2_score,accuracy_score,mean_absolute_error

print("r2_score: " ,r2_score(y_test,y_pred))
print("error: ",mean_absolute_error(y_test,y_pred))

# %%
#randomforest model


step1=ColumnTransformer(transformers=[
    ("col_trf",OneHotEncoder(sparse_output=False,drop="first"),[0,1,7,10,11])
],
remainder="passthrough")


step2=RandomForestRegressor(n_estimators=100,
                           random_state=3,
                           max_samples=0.5,
                           max_features=0.75,
                           max_depth=15)

pipe=Pipeline([
    ("step1",step1),
    ("step2",step2)
])

pipe.fit(x_train,y_train)

y_pred=pipe.predict(x_test)

from sklearn.metrics import r2_score,accuracy_score,mean_absolute_error

print("r2_score: " ,r2_score(y_test,y_pred))
print("error: ",mean_absolute_error(y_test,y_pred))
# Out:
# r2_score:  0.8805127747774116
# error:  0.16583854564050735

# %%
#adaboost regressor model


step1=ColumnTransformer(transformers=[
    ("col_trf",OneHotEncoder(sparse_output=False,drop="first"),[0,1,7,10,11])
],
remainder="passthrough")


step2=AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

pipe=Pipeline([
    ("step1",step1),
    ("step2",step2)
])

pipe.fit(x_train,y_train)

y_pred=pipe.predict(x_test)

from sklearn.metrics import r2_score,accuracy_score,mean_absolute_error

print("r2_score: " ,r2_score(y_test,y_pred))
print("error: ",mean_absolute_error(y_test,y_pred))
# Out:
# r2_score:  0.8036007581912341
# error:  0.2293421205569921

# %%
#gradianboostregressor


step1=ColumnTransformer(transformers=[
    ("col_trf",OneHotEncoder(sparse_output=False,drop="first"),[0,1,7,10,11])
],
remainder="passthrough")


step2=GradientBoostingRegressor(n_estimators=600)

pipe=Pipeline([
    ("step1",step1),
    ("step2",step2)
])

pipe.fit(x_train,y_train)

y_pred=pipe.predict(x_test)

from sklearn.metrics import r2_score,accuracy_score,mean_absolute_error

print("r2_score: " ,r2_score(y_test,y_pred))
print("error: ",mean_absolute_error(y_test,y_pred))
# Out:
# r2_score:  0.8973638992476662
# error:  0.15395211265593603

# %%
#xgboost


step1=ColumnTransformer(transformers=[
    ("col_trf",OneHotEncoder(sparse_output=False,drop="first"),[0,1,7,10,11])
],
remainder="passthrough")


step2=XGBRegressor(n_estimators=45,max_depth=5,learning_rate=0.5)

pipe=Pipeline([
    ("step1",step1),
    ("step2",step2)
])

pipe.fit(x_train,y_train)

y_pred=pipe.predict(x_test)

from sklearn.metrics import r2_score,accuracy_score,mean_absolute_error

print("r2_score: " ,r2_score(y_test,y_pred))
print("error: ",mean_absolute_error(y_test,y_pred))
# Out:
# r2_score:  0.8807254341553763
# error:  0.16863506294603067

# %%
import pickle


pickle.dump(df,open("df.pkl","wb"))
pickle.dump(pipe,open("pipe.pkl","wb"))

# %%
x_train.head(1)
# Out:
#     Company  TypeName  Ram  Weight  TouchScreen  Ips            Ppi  \
# 162    Dell  Notebook    8    2.13            0    0  236376.923077
#
#          Cpu_brand  HDD  SSD Gpu_brand       OS
# 162  Intel Core i5    0  256       AMD  Windows
